# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report




train_df = pd.read_csv('drive/My Drive/Colab Notebooks/icp4/Python_Lesson4/glass.csv')
X_train = train_df.drop("Type",axis=1)
Y_train = train_df["Type"]


X_train, X_test, Y_train, y_test= train_test_split(X_train, Y_train, test_size=0.4, random_state=0)
gnb = GaussianNB()

y_pred = gnb.fit(X_train, Y_train).predict(X_test)
gnb.fit(X_train, Y_train)
Y_pred = gnb.predict(X_test)
acc_gnb = round(gnb.score(X_train, Y_train) * 100, 2)
print("GNB accuracy is:",acc_gnb)
print(classification_report(y_test,Y_pred))
# Out:
# GNB accuracy is: 42.97
#               precision    recall  f1-score   support
#
#            1       0.33      0.04      0.06        28
#            2       0.56      0.15      0.24        33
#            3       0.16      0.73      0.26        11
#            5       0.20      0.50      0.29         2
#            6       0.43      1.00      0.60         3
#            7       0.82      1.00      0.90         9
#
#     accuracy                           0.31        86
#    macro avg       0.42      0.57      0.39        86
# weighted avg       0.45      0.31      0.27        86

# %%
from google.colab import drive
drive.mount('/content/drive/')
